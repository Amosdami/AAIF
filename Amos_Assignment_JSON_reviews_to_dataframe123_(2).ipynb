# %% [markdown]
# <a href="https://colab.research.google.com/github/Amosdami/AAIF/blob/main/Amos_Assignment_JSON_reviews_to_dataframe123_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing necessary libraries for data handling, visualization, and analysis

import json  # For working with JSON files
import pandas as pd  # Pandas for data manipulation and analysis
import matplotlib.pyplot as plt  # Matplotlib for static visualizations
import seaborn as sns  # Seaborn for statistical data visualization (built on Matplotlib)
import numpy as np  # Numpy for numerical operations
import plotly.express as px  # Plotly Express for interactive visualizations

# Natural Language Processing (NLP) Libraries
import re  # Regular expressions for text manipulation and pattern matching
from textblob import TextBlob  # For text processing and sentiment analysis
from wordcloud import WordCloud  # For creating word cloud visualizations

# Suppressing warnings to avoid unnecessary output during execution
import warnings
warnings.filterwarnings('ignore')

# %%
file_path = '/content/data3.json'
with open(file_path, 'r') as file:
    data = json.load(file)

# %%
reviews_data = []
count = 0
for result in data['results']:
  asin = result['content']["asin"]
  for review in result['content']['reviews']:
    count += 1
    try:
      review_info = {
      'review_id': review['id'],
      'product_id': asin,
      "title": review["title"],
      "author": review["author"],
      "rating": review["rating"],
      "content": review["content"],
      "timestamp": review["timestamp"],
      "profile_id": review["profile_id"],
      "is_verified": review["is_verified"],
      "helpful_count": review.get('helpful_count', 0),
      "product_attributes": review["product_attributes"]
      }
      reviews_data.append(review_info)
    except:
      print(count)
      break

reviews_df = pd.DataFrame(reviews_data)
reviews_df.to_csv('reviews_1.csv', index=False)
reviews_df
# Out:
#         review_id  product_id  \
# 0  R17C5FYARXA3U3  B094MWL5LY
# 1  R1LKWXIKOCUDGA  B094MWL5LY
# 2   RT1SDHBQF2RTR  B094MWL5LY
# 3  R1EVUI0UNVJK0O  B094MWL5LY
# 4  R1VNG2Z56I7G55  B094MWL5LY
# 5  R1IDDHUF6Z3OER  B094MWL5LY
# 6  R1DKR5KQEZN88R  B094MWL5LY
# 7   RZC7HJEG7RZ77  B094MWL5LY
# 8  R3S3LBPHP2998Z  B094MWL5LY
# 9   R3TGSKJ5E6ORA  B094MWL5LY
#
#                                                title            author  \
# 0               5.0 out of 5 stars Bang for the buck          Kalapasc
# 1  5.0 out of 5 stars Great speaker in a compact ...           Mr John
# 2                     4.0 out of 5 stars Works great    kelly martinez
# 3                   5.0 out of 5 stars Great speaker  David A Wheatley
# 4            5.0 out of 5 stars Great for a backpack  zack miastkowski
# 5    3.0 out of 5 stars NOT A BIG DEAL IN SOUND!!! 😕    Nicole Bronson
# 6                    5.0 out of 5 stars Good Product     Kenneth Zhang
# ...

# %%
len(reviews_df)
# Out:
# 10

# %%
df_1 = pd.read_csv('/content/merged_dataabitmax.csv')
df_2 = pd.read_csv('/content/merged_datalenure.csv')
df_3 = pd.read_csv('/content/merged_datamusibaby.csv')
df_4 = pd.read_csv('/content/merged_datazealot.csv')
df_5 = pd.read_csv('/content/new_datasetJBL CHARGE 5.csv')
df_6 = pd.read_csv('/content/new_datasetbeatspillip67 mate black.csv')
df_7 = pd.read_csv('/content/new_datasetbose soundlink color2.csv')
df_8 = pd.read_csv('/content/new_datasetbose soundlink flex.csv')
df_9 = pd.read_csv('/content/new_datasetjbl flip6.csv')
df_10 = pd.read_csv('/content/new_datasetsont ULT field.csv')
df_11 = pd.read_csv('/content/new_datasetsony SRS XG400.csv')
df_12 = pd.read_csv('/content/beatspillmerged_data.csv')

df_12.head()
# Out:
#         review_id  product_id  \
# 0   RJ3AF8BBR5LBU  B0D4STD5ZC
# 1  R2SSSH04J4J264  B0D4STD5ZC
# 2   R935PCZ92UVGL  B0D4STD5ZC
# 3  R2EVRTXO9M1YF7  B0D4STD5ZC
# 4   R4BQHA0TLLJNN  B0D4STD5ZC
#
#                                                title           author  rating  \
# 0  5.0 out of 5 stars Exactly what i was looking for  Amazon Customer       5
# 1  5.0 out of 5 stars Really nice portable speake...          Bruce C       5
# 2                      5.0 out of 5 stars Very Happy        B. Hinson       5
# 3           4.0 out of 5 stars Is it the JBL killer?            Tommy       4
# 4  5.0 out of 5 stars The best Speaker I have eve...             Leox       5
#
#                                              content  \
# 0  Sleek. Compact. Well built. Great sound. Water...
# 1  Needed a new portable speaker for the home set...
# 2  We bought this for a trip to the beach and it ...
# 3  I bought this because it was on sale, and I al...
# ...

# %%
merged_df = pd.concat([df_1,
                       df_2,
                       df_3,
                       df_4,
                       df_5,
                       df_6,
                       df_7,
                       df_8,
                       df_9,
                       df_10,
                       df_11,
                       df_12],
                      ignore_index=True)
merged_df
# Out:
#            review_id  product_id  \
# 0     R2W2QT9LRXD6FX  B0CDPZXJ2V
# 1     R2JFHV5XVFT65B  B0CDPZXJ2V
# 2     R2G0MT340ZUZS6  B0CDPZXJ2V
# 3     R1U91NO9ZS5N2O  B0CDPZXJ2V
# 4     R166OEM7NYJ4DX  B0CDPZXJ2V
# ...              ...         ...
# 1378  R16YQMK6DBJQBM  B0D4STD5ZC
# 1379   R2H42JDX6Y37E  B0D4STD5ZC
# 1380  R3L2A88GOC5G6I  B0D4STD5ZC
# 1381   R99X2DXJ9IWPM  B0D4STD5ZC
# 1382  R2AZVHS8KVEN85  B0D4STD5ZC
#
#                                                   title  \
# 0     5.0 out of 5 stars Compact Powerhouse: The Ult...
# 1              5.0 out of 5 stars Portable & Rich Audio
# 2         5.0 out of 5 stars BUY IT, you won't regret !
# 3     3.0 out of 5 stars Sounds Like A 1976 Transist...
# 4                       4.0 out of 5 stars Great Value.
# ...                                                 ...
# 1378  3.0 out of 5 stars Great sound, but MONO ruins...
# 1379          5.0 out of 5 stars Best beats pill ever !
# ...

# %% [markdown]
# **Checking the Last Three Rows of the Data Merged**

# %%
merged_df.tail(3)
# Out:
#            review_id  product_id  \
# 1380  R3L2A88GOC5G6I  B0D4STD5ZC
# 1381   R99X2DXJ9IWPM  B0D4STD5ZC
# 1382  R2AZVHS8KVEN85  B0D4STD5ZC
#
#                                                   title        author  rating  \
# 1380                    5.0 out of 5 stars Good speaker    Oli Rivers       5
# 1381                       5.0 out of 5 stars Rlly good  Luis dejesus       5
# 1382  1.0 out of 5 stars Switches off quickly and un...      Dr. Help       1
#
#                                                 content  \
# 1380  The media could not be loaded. For a smallish ...
# 1381  The media could not be loaded. Great audio lou...
# 1382  Had great hopes for this speaker, but unfortun...
#
#                                         timestamp  \
# 1380   Reviewed in the United States July 1, 2024
# 1381   Reviewed in the United States July 2, 2024
# 1382  Reviewed in the United States July 31, 2024
#
#                         profile_id  is_verified  helpful_count  \
# ...

# %% [markdown]
# **Checking the Merged Data Structure**

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1383 entries, 0 to 1382
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   review_id           1383 non-null   object
#  1   product_id          1383 non-null   object
#  2   title               1383 non-null   object
#  3   author              1382 non-null   object
#  4   rating              1383 non-null   int64
#  5   content             1382 non-null   object
#  6   timestamp           1383 non-null   object
#  7   profile_id          1383 non-null   object
#  8   is_verified         1383 non-null   bool
#  9   helpful_count       1383 non-null   int64
#  10  product_attributes  1311 non-null   object
# dtypes: bool(1), int64(2), object(8)
# memory usage: 109.5+ KB

# %% [markdown]
# Based on the .info() method output, here is a detailed data description, explaining exactly what each column means:
#
# * review_id: A unique identifier for each review (string).
# * product_id: A unique identifier for each product reviewed (string).
# * title: The title or headline of the review, often summarizing the reviewer's opinion (string).
# * author: The name or username of the person who wrote the review (string, with 2 missing values).
# * rating: The numerical rating given by the reviewer, typically on a scale from 1 to 5 stars (integer).
# * content: The full text content of the review, detailing the reviewer's experience and opinions (string, with 1 missing value).
# * timestamp: The date and time when the review was posted (string).
# * profile_id: A unique identifier for the profile of the reviewer (string).
# * is_verified: A boolean value indicating whether the reviewer is a verified purchaser (True for verified, False for not verified).
# * helpful_count: The number of times other users marked the review as helpful (integer).
# * product_attributes: Additional attributes or details about the product, such as color, style, and pattern (string, with 100 missing values).

# %% [markdown]
# ## **Checking the Count of Missing Values**

# %%
merged_df.isnull().sum()
# Out:
# review_id              0
# product_id             0
# title                  0
# author                 1
# rating                 0
# content                1
# timestamp              0
# profile_id             0
# is_verified            0
# helpful_count          0
# product_attributes    72
# dtype: int64

# %% [markdown]
# Three features contain missing values: 'author', 'content', and 'product_attributes', with 'product_attributes' having the highest number, at 72 missing values. Further investigation is required to assess the impact of these missing values on the analysis and to determine whether these features are essential.

# %% [markdown]
# ### **Inspecting the Columns**

# %%
merged_df.columns
# Out:
# Index(['review_id', 'product_id', 'title', 'author', 'rating', 'content',
#        'timestamp', 'profile_id', 'is_verified', 'helpful_count',
#        'product_attributes'],
#       dtype='object')

# %% [markdown]
# ## **Product and Price Mapping**

# %%
product_map = merged_df["product_id"].nunique()
product_map
# Out:
# 15

# %%
# Getting unique product IDs and convert to a list
product_map = merged_df["product_id"].unique().tolist()
product_map
# Out:
# ['B0CDPZXJ2V',
#  'B0D4STD5ZC',
#  'B0CM2WNR7V',
#  'B094MWL5LY',
#  'B0CMQ667QV',
#  'B094LS37Z4',
#  'B0748N1BZD',
#  'B0D4SX9RC6',
#  'B0CPYPGH5R',
#  'B01HETFQKI',
#  'B01HETFPK4',
#  'B09GJVTRNZ',
#  'B0CXL5KTBD',
#  'B0B43Y8GHZ',
#  'B0B44581YM']

# %%
# Dictionary mapping product IDs to Product Names
product_names = {
    'B0D4STD5ZC': 'Beats_pill Red',
    'B0D4SX9RC6': 'beats pill matte black',
    'B094MWL5LY': 'MUSI BABY Bluetooth speaker',
    'B0CMQ667QV': 'Zealot bluetooth speaker',
    'B0CDPZXJ2V': 'Abitmax bluetooth speaker',
    'B094LS37Z4': 'JBL Charge5',
    'B0CPYPGH5R': 'Bose soundlink flex',
    'B0CM2WNR7V': 'lenure bluetooth',
    'B0B43Y8GHZ': 'Sony SRS Xseries bluetooth speaker',
    'B01HETFQKI': 'bose soundlink color 2',
    'B0CXL5KTBD': 'Sony ult',
    'B09GJVTRNZ': 'JBL FLIP 6',
    'B01HETFPK4': 'bose collor 2 blue',
    'B0748N1BZD': 'bose soundlink micro speaker'}

# %% [markdown]
# ## **Mapping of Product to Prices**

# %%
# Dictionary mapping product IDs to Prices
product_prices = {
    'B0D4STD5ZC': 134,
    'B0D4SX9RC6': 149,
    'B094MWL5LY': 31,
    'B0CMQ667QV': 189,
    'B0CDPZXJ2V': 18,
    'B094LS37Z4': 129,
    'B0CPYPGH5R': 149,
    'B0CM2WNR7V': 9,
    'B01HETFQKI': 189,
    'B0CXL5KTBD': 98,
    'B09GJVTRNZ': 118,
    'B01HETFPK4': 144,
    'B0B43Y8GHZ': 189,
    'B0748N1BZD': 119,}

# %%
# Add Product Name column
merged_df['product_name'] = merged_df['product_id'].map(product_names)

# Add Product Price column
merged_df['product_price'] = merged_df['product_id'].map(product_prices)

# Hard encoding for is_verified column
merged_df['is_verified_encoded'] = merged_df['is_verified'].apply(lambda x: 1 if x else 0)

# Display the updated DataFrame
merged_df
# Out:
#            review_id  product_id  \
# 0     R2W2QT9LRXD6FX  B0CDPZXJ2V
# 1     R2JFHV5XVFT65B  B0CDPZXJ2V
# 2     R2G0MT340ZUZS6  B0CDPZXJ2V
# 3     R1U91NO9ZS5N2O  B0CDPZXJ2V
# 4     R166OEM7NYJ4DX  B0CDPZXJ2V
# ...              ...         ...
# 1378  R16YQMK6DBJQBM  B0D4STD5ZC
# 1379   R2H42JDX6Y37E  B0D4STD5ZC
# 1380  R3L2A88GOC5G6I  B0D4STD5ZC
# 1381   R99X2DXJ9IWPM  B0D4STD5ZC
# 1382  R2AZVHS8KVEN85  B0D4STD5ZC
#
#                                                   title  \
# 0     5.0 out of 5 stars Compact Powerhouse: The Ult...
# 1              5.0 out of 5 stars Portable & Rich Audio
# 2         5.0 out of 5 stars BUY IT, you won't regret !
# 3     3.0 out of 5 stars Sounds Like A 1976 Transist...
# 4                       4.0 out of 5 stars Great Value.
# ...                                                 ...
# 1378  3.0 out of 5 stars Great sound, but MONO ruins...
# 1379          5.0 out of 5 stars Best beats pill ever !
# ...

# %% [markdown]
# Each product name and price were mapped to their corresponding product ID for clarity and to facilitate easy identification during analysis. Additionally, new columns were created for these features to enable further analysis of how each product influences customer choice.

# %% [markdown]
# ## Inspecting the Columns with Missing **Values**

# %%
miss_val = merged_df[merged_df[['author', 'content', 'product_price', 'product_name', 'product_attributes']].isna().any(axis=1)]
miss_val.head()
# Out:
#         review_id  product_id  \
# 0  R2W2QT9LRXD6FX  B0CDPZXJ2V
# 1  R2JFHV5XVFT65B  B0CDPZXJ2V
# 2  R2G0MT340ZUZS6  B0CDPZXJ2V
# 3  R1U91NO9ZS5N2O  B0CDPZXJ2V
# 4  R166OEM7NYJ4DX  B0CDPZXJ2V
#
#                                                title  \
# 0  5.0 out of 5 stars Compact Powerhouse: The Ult...
# 1           5.0 out of 5 stars Portable & Rich Audio
# 2      5.0 out of 5 stars BUY IT, you won't regret !
# 3  3.0 out of 5 stars Sounds Like A 1976 Transist...
# 4                    4.0 out of 5 stars Great Value.
#
#                         author  rating  \
# 0                          Ned       5
# 1              Bhavani Bhaskar       5
# 2                  Prakashraaz       5
# 3                     cohocook       3
# 4  dirk diggler/jack mayhoffer       4
#
#                                              content  \
# 0  I got this portable speaker from Amazon and, l...
# 1  Got my hands on this incredible Bluetooth spea...
# ...

# %%
miss_val_subset = miss_val[['author', 'content', 'product_price', 'product_name', 'product_attributes']]
miss_val_subset
# Out:
#                            author  \
# 0                             Ned
# 1                 Bhavani Bhaskar
# 2                     Prakashraaz
# 3                        cohocook
# 4     dirk diggler/jack mayhoffer
# ...                           ...
# 155                    Fred Lopez
# 156            Nicholas Schipiour
# 539                  CRAIG WATSON
# 729                           NaN
# 1205                Karla A Rhein
#
#                                                 content  product_price  \
# 0     I got this portable speaker from Amazon and, l...           18.0
# 1     Got my hands on this incredible Bluetooth spea...           18.0
# 2     I really like this Bluetooth speaker; it's sma...           18.0
# 3     It's a $20 shower speaker so I'll deal with th...           18.0
# 4     Nice and compact. Good volume. Excellent price...           18.0
# ...                                                 ...            ...
# ...

# %% [markdown]
# ## **Checking through the Rows with Missing Values**

# %%
miss_val.head()
# Out:
#         review_id  product_id  \
# 0  R2W2QT9LRXD6FX  B0CDPZXJ2V
# 1  R2JFHV5XVFT65B  B0CDPZXJ2V
# 2  R2G0MT340ZUZS6  B0CDPZXJ2V
# 3  R1U91NO9ZS5N2O  B0CDPZXJ2V
# 4  R166OEM7NYJ4DX  B0CDPZXJ2V
#
#                                                title  \
# 0  5.0 out of 5 stars Compact Powerhouse: The Ult...
# 1           5.0 out of 5 stars Portable & Rich Audio
# 2      5.0 out of 5 stars BUY IT, you won't regret !
# 3  3.0 out of 5 stars Sounds Like A 1976 Transist...
# 4                    4.0 out of 5 stars Great Value.
#
#                         author  rating  \
# 0                          Ned       5
# 1              Bhavani Bhaskar       5
# 2                  Prakashraaz       5
# 3                     cohocook       3
# 4  dirk diggler/jack mayhoffer       4
#
#                                              content  \
# 0  I got this portable speaker from Amazon and, l...
# 1  Got my hands on this incredible Bluetooth spea...
# ...

# %% [markdown]
# Upon closer inspection of the rows with missing values in the 'product attribute' column, it was observed that the values were not provided by the customers. missing values ('NaN') were later replaced with 'Unknown' during data cleaning. Given that this feature represents the product's color—a potential factor influencing pricing, further investigation is warranted to evaluate its impact.

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# ## **Creating a Copy Before Cleaning**

# %%
cleaned_df = merged_df.copy()
cleaned_df.dropna(subset=['content'], inplace=True)
cleaned_df.head(2)
# Out:
#         review_id  product_id  \
# 0  R2W2QT9LRXD6FX  B0CDPZXJ2V
# 1  R2JFHV5XVFT65B  B0CDPZXJ2V
#
#                                                title           author  rating  \
# 0  5.0 out of 5 stars Compact Powerhouse: The Ult...              Ned       5
# 1           5.0 out of 5 stars Portable & Rich Audio  Bhavani Bhaskar       5
#
#                                              content  \
# 0  I got this portable speaker from Amazon and, l...
# 1  Got my hands on this incredible Bluetooth spea...
#
#                                          timestamp  \
# 0  Reviewed in the United States November 26, 2023
# 1   Reviewed in the United States February 5, 2024
#
#                      profile_id  is_verified  helpful_count  \
# 0  AGN2CAS2GVFZTBZ7TWDZOQMAIZSQ         True              1
# 1  AG22XAZU2NL72WTPHBMAPN36D4BQ         True              2
#
#   product_attributes               product_name  product_price  \
# ...

# %%
cleaned_df.isnull().sum()
# Out:
# review_id               0
# product_id              0
# title                   0
# author                  1
# rating                  0
# content                 0
# timestamp               0
# profile_id              0
# is_verified             0
# helpful_count           0
# product_attributes     72
# product_name            1
# product_price           1
# is_verified_encoded     0
# dtype: int64

# %%
miss_val = merged_df[merged_df[['product_price','product_name', ]].isna().any(axis=1)]
# Use merged_df instead of cleaned_df to create the boolean index.
# This ensures that the index used to filter aligns with the DataFrame being filtered (merged_df).
miss_val.head(100)
# Out:
#            review_id  product_id                          title  \
# 1205  R2US9HAURRDRY0  B0B44581YM  5.0 out of 5 stars Good sound
#
#              author  rating  \
# 1205  Karla A Rhein       5
#
#                                                 content  \
# 1205  Love my new Sony speaker. Use it out by the po...
#
#                                             timestamp  \
# 1205  Reviewed in the United States September 2, 2024
#
#                         profile_id  is_verified  helpful_count  \
# 1205  AGCH7QEIEJNCVLXYECCKEASBOBDQ         True              0
#
#                      product_attributes product_name  product_price  \
# 1205  Color: Light GrayStyle: SRS-XE200          NaN            NaN
#
#       is_verified_encoded
# 1205                    1

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1382 entries, 0 to 1382
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   review_id            1382 non-null   object
#  1   product_id           1382 non-null   object
#  2   title                1382 non-null   object
#  3   author               1381 non-null   object
#  4   rating               1382 non-null   int64
#  5   content              1382 non-null   object
#  6   timestamp            1382 non-null   object
#  7   profile_id           1382 non-null   object
#  8   is_verified          1382 non-null   bool
#  9   helpful_count        1382 non-null   int64
#  10  product_attributes   1310 non-null   object
#  11  product_name         1381 non-null   object
#  12  product_price        1381 non-null   float64
#  13  is_verified_encoded  1382 non-null   int64
# dtypes: bool(1), float64(1), int64(3), object(9)
# memory usage: 152.5+ KB

# %%
cleaned_df["review_id"].nunique()
# Out:
# 865

# %%
cleaned_df["product_attributes"].nunique()
# Out:
# 33

# %% [markdown]
# ## **Replacing the Null Values in 'Product Attributes' with 'Not Specified'**

# %%
cleaned_df['author'].fillna('Unknown', inplace=True)
cleaned_df['product_attributes'].fillna('Not Specified', inplace=True)
cleaned_df['product_price'].fillna('Not Specified', inplace=True)
cleaned_df['product_name'].fillna('Not Specified', inplace=True)

# Checking if there are missing values after cleaning
print("Missing values after handling:")
print(cleaned_df.isna().sum())
# Out:
# Missing values after handling:
# review_id              0
# product_id             0
# title                  0
# author                 0
# rating                 0
# content                0
# timestamp              0
# profile_id             0
# is_verified            0
# helpful_count          0
# product_attributes     0
# product_name           0
# product_price          0
# is_verified_encoded    0
# dtype: int64

# %%
cleaned_df.to_csv('cleanedDF.csv', index=False)

# %% [markdown]
# All missing values have been addressed, and we now have a cleaned dataset ready for Exploratory Data Analysis (EDA).

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# **Summary Statistics**

# %%
cleaned_df.describe()
# Out:
#             rating  helpful_count  is_verified_encoded
# count  1382.000000    1382.000000          1382.000000
# mean      4.549928       3.523155             0.808973
# std       0.958991      31.845445             0.393253
# min       1.000000       0.000000             0.000000
# 25%       5.000000       0.000000             1.000000
# 50%       5.000000       0.000000             1.000000
# 75%       5.000000       1.000000             1.000000
# max       5.000000     795.000000             1.000000

# %% [markdown]
# The data shows an average rating of 4.48, with most scores being perfect 5s. Nearly 97% of the ratings are from verified users, but the average helpful count is about 0.69, meaning not every rating is seen as helpful. Overall, users are mostly satisfied, but opinions on helpfulness differ.

# %%
mean_rating = cleaned_df['rating'].mean()
median_rating = cleaned_df['rating'].median()
mode_rating = cleaned_df['rating'].mode()[0]


plt.figure(figsize=(10, 6))

# Plotting the histogram
sns.histplot(cleaned_df['rating'], bins=5, kde=True, color='skyblue', stat='density', alpha=0.6)

# Adding vertical lines for mean, median, and mode
plt.axvline(mean_rating, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_rating:.2f}')
plt.axvline(median_rating, color='green', linestyle='dashed', linewidth=2, label=f'Median: {median_rating:.2f}')
plt.axvline(mode_rating, color='orange', linestyle='dashed', linewidth=2, label=f'Mode: {mode_rating:.2f}')

# Adding labels and title
plt.xlabel('Rating')
plt.ylabel('Density')
plt.title('Rating Distribution with Mean, Median, and Mode')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# The plot shows a left-skewed distribution, with most ratings clustered around 4.5 to 5.0, indicating generally high customer satisfaction. The mean rating is 4.47, while both the median and mode are 5.00, showing that most users give the highest possible rating. This suggests a strong positive bias in the feedback. However, the slight gap between the mean and the other metrics indicates the presence of some lower ratings, which may warrant further investigation.

# %% [markdown]
# ## **Identifying and Handling Outliers**
#
# *Using the IQR method*

# %%
# Creating a figure with subplots for each numerical column
plt.figure(figsize=(18, 6))

# Box plot for rating
plt.subplot(1, 3, 1)
sns.boxplot(x=cleaned_df['rating'])
plt.title('Box Plot for Rating')

# Box plot for helpful_count
plt.subplot(1, 3, 2)
sns.boxplot(x=cleaned_df['helpful_count'])
plt.title('Box Plot for Helpful Count')

# Box plot for product price
plt.subplot(1, 3, 3)
# Convert 'product_price' column to numeric, handling errors
cleaned_df['product_price'] = pd.to_numeric(cleaned_df['product_price'], errors='coerce')
sns.boxplot(x=cleaned_df['product_price'])
plt.title('Box Plot for Product Price')

plt.tight_layout()
plt.show()

# %% [markdown]
# The box plot shows only 2 outliers for the rating column, both of which are in the range of 1.0 to 2.0. However, there are many outliers for the helpful_count column. Given the nature of the helpful_count metric, it's plausible for certain reviews to receive significantly more helpful votes compared to others. Therefore, these values should not be automatically considered as outliers in the traditional sense.

# %% [markdown]
# ### Checking Rating Value Counts

# %%
# Calculating rating value counts
rating_counts = cleaned_df['rating'].value_counts().sort_index()

# Calculating percentage of each rating
rating_percentage = (rating_counts / rating_counts.sum()) * 100

print("Rating Value Counts:\n", rating_counts)
print("\nRating Percentage:\n", rating_percentage)
# Out:
# Rating Value Counts:
#  rating
# 1      48
# 2      34
# 3      74
# 4     180
# 5    1046
# Name: count, dtype: int64
#
# Rating Percentage:
#  rating
# 1     3.473227
# 2     2.460203
# 3     5.354559
# 4    13.024602
# 5    75.687410
# Name: count, dtype: float64

# %% [markdown]
# **Visualizing the Percentage of Ratings**

# %%
# Create a bar plot for rating percentages
plt.figure(figsize=(10, 6))
sns.barplot(x=rating_percentage.index,
            y=rating_percentage.values,
            palette='deep')
plt.title('Percentage of Ratings')
plt.xlabel('Rating')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The rating value counts plot shows that 68.24% of reviews are 5-star ratings, indicating strong customer satisfaction. The 4-star ratings, at 17.98%, suggest general approval, while 3-star ratings (7.98%) reflect mixed feelings. The lower ratings—2 stars at 3.87% and 1 star at 1.93%—are less common, indicating fewer dissatisfied customers.

# %% [markdown]
# ## **Reviews with a Rating of 3**

# %%
# Extract the content of reviews with a rating of 3
rating_3_content = cleaned_df[cleaned_df['rating'] == 3]['content']

# Display the results
print(rating_3_content)
# Out:
# 3       It's a $20 shower speaker so I'll deal with th...
# 41      Wait for a sale because while it sounds good a...
# 46      The new pill looks awesome, and built extremel...
# 89      This Bluetooth speaker is on the higher end of...
# 90      I was stoked to try a speaker from Beats with ...
#                               ...
# 1294    I was stoked to try a speaker from Beats with ...
# 1329    Wait for a sale because while it sounds good a...
# 1334    The new pill looks awesome, and built extremel...
# 1377    This Bluetooth speaker is on the higher end of...
# 1378    I was stoked to try a speaker from Beats with ...
# Name: content, Length: 74, dtype: object

# %%
# Filter reviews with a rating of 3
three_star_reviews = cleaned_df[cleaned_df['rating'] == 3]
three_star_reviews.head(2)
# Out:
#          review_id  product_id  \
# 3   R1U91NO9ZS5N2O  B0CDPZXJ2V
# 41  R3EIAFTJO1Q4PC  B0D4STD5ZC
#
#                                                 title    author  rating  \
# 3   3.0 out of 5 stars Sounds Like A 1976 Transist...  cohocook       3
# 41                     3.0 out of 5 stars Overpriced.    ERIK H       3
#
#                                               content  \
# 3   It's a $20 shower speaker so I'll deal with th...
# 41  Wait for a sale because while it sounds good a...
#
#                                           timestamp  \
# 3   Reviewed in the United States February 21, 2024
# 41  Reviewed in the United States September 1, 2024
#
#                       profile_id  is_verified  helpful_count  \
# 3   AGPSLG54PNNMYMXB74CBKZGAP7NA         True              1
# 41  AEIHKCJB7ZYF6NDKKZTCL2IZS6GQ         True              0
#
#                                    product_attributes  \
# 3                                       Not Specified
# ...

# %% [markdown]
# **Checking Reviews Column by Verified and Non-Verified**

# %%
verified_counts = cleaned_df['is_verified'].value_counts()
print("Verified vs Non-Verified Profiles:\n", verified_counts)
# Out:
# Verified vs Non-Verified Profiles:
#  is_verified
# True     1118
# False     264
# Name: count, dtype: int64

# %% [markdown]
# **Plot Reviews Distribution Count Using Bar Plot**

# %%
plt.bar(verified_counts.index.astype(str), verified_counts.values)
plt.xlabel('Verified Status')
plt.ylabel('Count of Profiles')
plt.title('Distribution of Verified and Non-Verified Profiles')
plt.xticks([0, 1], ['Non-Verified', 'Verified'])
plt.show()

# %% [markdown]
# The plot shows that the number of users with non verified accounts who provided reviews is predominantly higher than that of verified profiles. This suggests that non verified users are more engaged in sharing their feedback, indicating a stronger presence of credibility on the data scrapped

# %% [markdown]
# **Percentage Distribution Count**

# %%
percentage_distribution = (verified_counts / verified_counts.sum()) * 100
print("Percentage Distribution of Verified Reviews:\n", percentage_distribution)
# Out:
# Percentage Distribution of Verified Reviews:
#  is_verified
# True     80.89725
# False    19.10275
# Name: count, dtype: float64

# %% [markdown]
#  Percentage Distribution Group by Price, Color, and Rating

# %%
# Get unique product names and their prices
product_price = cleaned_df[['product_name',
                            'product_price']].drop_duplicates()

# Sorting by product price
product_price = product_price.sort_values(by='product_price')

# Setting up the plot
plt.figure(figsize=(12, 6))

# Generate a list of colors (you can customize this)
colors = plt.cm.viridis(np.linspace(0,
                                    1,
                                    len(product_price)))

# Convert product names to strings explicitly
product_names = product_price['product_name'].astype(str)
product_prices = product_price['product_price']

# Plotting
plt.barh(product_names, product_prices, color=colors)

# Adding labels and title
plt.xlabel('Product Price')
plt.ylabel('Product Name')
plt.title('Price Distribution of Products')

# Displaying the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# The bar plots illustrate the price distribution of various audio products. The bose soundlink color 2 tops the chart with a price close to $200.00, followed closely by the zealoy speaker. The Beats Pill and Bose SoundLink Flex maintain a similar price range, highlighting their competitive pricing.
#
# On the lower end of the spectrum, the lenure bluetooth speaker is the least expensive.
#
# An investigation into the price reductions observed during the data scraping process revealed that some products offer substantial discounts. These discounts are likely implemented to attract more customers, which consequently leads to a reduction in the listed price.

# %%
# Grouping the data by product name, price, and rating
price_rating_counts = cleaned_df.groupby(['product_name',
                                          'product_price',
                                          'rating']).size().reset_index(name='counts')

# Sorting the grouped data by counts in descending order
price_rating_counts = price_rating_counts.sort_values(by ='counts', ascending=False)

# Plotting the price and rating distribution
plt.figure(figsize=(12, 6))
for rating, grp in price_rating_counts.groupby('rating'):
    plt.barh(grp['product_name'],
             grp['counts'],
             label=f'Rating: {rating}')

plt.xlabel('Count')
plt.ylabel('Product Name')
plt.title('Price Distribution of Products by Rating')
plt.legend(title='Rating')
plt.tight_layout()
plt.show()

# %% [markdown]
# This bar chart represents the price distribution of different products by customer ratings. Each product is grouped based on its rating, and the length of each bar reflects the number of reviews at each rating level. Most products have received a high number of 5-star ratings (purple), indicating overall customer satisfaction, while a few products like Bose SoundLink color 2 have noticeable 4-star ratings (red). The chart shows that while most products maintain high ratings, the count of lower ratings is relatively minimal.

# %% [markdown]
# ## **How Product Prices Impact Ratings**

# %%
# Create an interactive scatter plot with product name, price, and rating
fig = px.scatter(price_rating_counts,
                 x='product_price',
                 y='rating',
                 size='counts',
                 color='rating',
                 hover_name='product_name',
                 title='Price vs Rating Distribution for Products',
                 labels={'product_price':'Product Price', 'rating':'Rating'},
                 size_max=20)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The interactive plot highlights the impact of price on product ratings. The lenure blutooth, one of the cheapest products, has a significantly lower number of 5-star reviews , and also the highest number of 1-star ratings, suggesting mixed feedback despite its affordability. The Sony ULT Field 1, priced at $98.00, shows strong customer satisfaction with no ratings below 3 stars, indicating a well-received product at a budget-friendly price point.
#
# In comparison, the Beats Pill, priced at 149.95, has a high number of 5-star ratings and minimal low ratings. However, the presence of 1-star reviews warrants further investigation. Higher-priced products like the Bose SoundLink and Sony SRS-XG300, both in the $189.99–$200 range, exhibit a wide range of ratings, with substantial reviews across all rating levels.
#
# This comparison shows that while Beats Pill performs well in terms of customer satisfaction, certain competitor products, particularly in lower price ranges, also offer high ratings, suggesting that price alone may not dictate overall satisfaction.

# %% [markdown]
# ## **Correlation Matrix**

# %%
# Selecting only numeric columns for correlation
numeric_df = cleaned_df.select_dtypes(include=[np.number])

# Calculating the correlation matrix
correlation_matrix = numeric_df.corr()

# Optional: Visualize the correlation matrix using a heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Correlation Matrix of Numeric Features')
plt.show()

# %% [markdown]
# **Correlation Analysis**

# %%
correlation_matrix
# Out:
#                        rating  helpful_count  product_price  \
# rating               1.000000      -0.037098      -0.007642
# helpful_count       -0.037098       1.000000       0.045972
# product_price       -0.007642       0.045972       1.000000
# is_verified_encoded -0.049575       0.038689       0.161989
#
#                      is_verified_encoded
# rating                         -0.049575
# helpful_count                   0.038689
# product_price                   0.161989
# is_verified_encoded             1.000000

# %% [markdown]
# ### **Correlation Matrix Report**
# This report summarizes the relationships among product rating, helpful count, product price, and verified reviewer status.
#
# - Rating and Helpful Count: Correlation of -0.03 indicates a very weak negative relationship, suggesting that the helpfulness of reviews does not significantly affect ratings.
#
# - Rating and Product Price: A correlation of -0.0076 shows almost no relationship, meaning product price does not influence ratings.
#
# - Rating and Verified Profile Status: The correlation of -0.049 indicates negligible impact of profile verification on ratings.
#
# - Helpful Count and Product Price: With a correlation of 0.046, there is a weak positive relationship, suggesting higher-priced products may have slightly more helpful reviews.
#
# - Helpful Count and Verified Profile Status: A correlation of 0.03 reflects a low influence of verified profiles on review helpfulness.
#
# - Product Price and Verified Profile Status: The correlation of 0.16 shows slight relationship between price and profile verification.
#
# Overall, the variables show weak or negligible correlations, indicating they operate largely independently within the dataset.

# %% [markdown]
# **Calculating variance and standard deviation for numeric features**

# %%
# Select only numeric columns from the cleaned DataFrame
numeric_df = cleaned_df.select_dtypes(include=[np.number])

# Calculate variance and standard deviation for numeric columns
variance = numeric_df.var()
std_deviation = numeric_df.std()

# Print the results
print("Variance:\n", variance)
print("\nStandard Deviation:\n", std_deviation)
# Out:
# Variance:
#  rating                    0.919663
# helpful_count          1014.132338
# product_price          1660.709892
# is_verified_encoded       0.154648
# dtype: float64
#
# Standard Deviation:
#  rating                  0.958991
# helpful_count          31.845445
# product_price          40.751808
# is_verified_encoded     0.393253
# dtype: float64

# %%
# Calculate the covariance matrix
covariance_matrix = numeric_df.cov()
covariance_matrix
# Out:
#                        rating  helpful_count  product_price  \
# rating               0.919663      -1.132945      -0.298730
# helpful_count       -1.132945    1014.132338      59.681839
# product_price       -0.298730      59.681839    1660.709892
# is_verified_encoded -0.018696       0.484513       2.596723
#
#                      is_verified_encoded
# rating                         -0.018696
# helpful_count                   0.484513
# product_price                   2.596723
# is_verified_encoded             0.154648

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(covariance_matrix,
            annot=True,
            fmt='.2f',
            cmap='coolwarm',
            square=True)
plt.title('Covariance Matrix Heatmap for Numerical Data')
plt.tight_layout()
plt.show()

# %% [markdown]
# The variance and standard deviation for the dataset reveal the following:
#
# - The rating has a variance of 0.91 and a standard deviation of 0.95, indicating moderate variability among ratings.
# - The helpful count shows high variability with a variance of 1014.13 and a standard deviation of 31.84.
# - Product price exhibits significant variation with a variance of 1562.271792 and a standard deviation of 39.52.
# - The verified profile status has low variance (0.15) and standard deviation (0.39), suggesting minimal variability in verification among reviewers.
#
# Overall, the ratings and helpful counts vary considerably, while the verification status remains relatively stable.

# %%
import scipy.stats as stats

def calculate_skewness_kurtosis(cleaned_df, product_price):
    """
    Calculate the skewness and kurtosis of a column in a DataFrame.

    Parameters:
    df (DataFrame): The input DataFrame.
    col (str): The name of the column.

    Returns:
    tuple: A tuple containing skewness and kurtosis.
"""

    skewness = cleaned_df['product_price'].skew()
    kurtosis = stats.kurtosis(cleaned_df['product_price']) # Changed data to cleaned_df['product_price']

    return skewness, kurtosis

# Moved the function call and variable assignment outside the function definition
skew_check, kurt_check = calculate_skewness_kurtosis(cleaned_df, "product_price")
print(f"Skewness: {skew_check}, Kurtosis: {kurt_check}")
# Out:
# Skewness: -1.292146970338398, Kurtosis: nan

# %% [markdown]
# # **Sentiment Analysis**

# %% [markdown]
# ## **Preprocessing Data For Sentiment Analysis**

# %% [markdown]
# Loading the Features needed for Sentiment Analysis

# %%
# Ensure column names are clean
cleaned_df.columns = cleaned_df.columns.str.strip()

# Correct way to select multiple columns
content_df = cleaned_df[['product_name',
                         'author',
                         'content',
                         'rating']]
content_df.head()
# Out:
#                 product_name                       author  \
# 0  Abitmax bluetooth speaker                          Ned
# 1  Abitmax bluetooth speaker              Bhavani Bhaskar
# 2  Abitmax bluetooth speaker                  Prakashraaz
# 3  Abitmax bluetooth speaker                     cohocook
# 4  Abitmax bluetooth speaker  dirk diggler/jack mayhoffer
#
#                                              content  rating
# 0  I got this portable speaker from Amazon and, l...       5
# 1  Got my hands on this incredible Bluetooth spea...       5
# 2  I really like this Bluetooth speaker; it's sma...       5
# 3  It's a $20 shower speaker so I'll deal with th...       3
# 4  Nice and compact. Good volume. Excellent price...       4

# %% [markdown]
# Cleaning the Data for Analysis

# %%
content_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1382 entries, 0 to 1382
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  1382 non-null   object
#  1   author        1382 non-null   object
#  2   content       1382 non-null   object
#  3   rating        1382 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 54.0+ KB

# %%
content_df.duplicated().sum()
# Out:
# 425

# %%
content_df['rating'].unique()
# Out:
# array([5, 3, 4, 2, 1])

# %% [markdown]
# Noise Entity Removal
#
# - Removing unwanted words, characters, and special patterns

# %%
def clean_text_simple(content):
    """
    Clean the input text by removing specific unwanted text, converting to lowercase,
    and removing specified characters or patterns.

    Parameters:
    text (str): The text to be cleaned.

    Returns:
    str: The cleaned text.
    """

    # Convert to lowercase for uniformity
    content = content.lower()

    # Remove specific characters or patterns
    # Example: Removing ellipsis (...) and other patterns if needed
    text = re.sub(r'\.\.\.', '', content)  # Removes ellipsis
    text = re.sub(r'\'s', '', content)  # Removes 's
    content = content.replace('-', '')  # Removes hyphens

    return content

# Apply the cleaning function to the 'reviews' column of the dataframe
content_df['Contents'] = content_df['content'].apply(clean_text_simple)

# Display the first few rows of the cleaned dataframe
content_df.head()
# Out:
#                 product_name                       author  \
# 0  Abitmax bluetooth speaker                          Ned
# 1  Abitmax bluetooth speaker              Bhavani Bhaskar
# 2  Abitmax bluetooth speaker                  Prakashraaz
# 3  Abitmax bluetooth speaker                     cohocook
# 4  Abitmax bluetooth speaker  dirk diggler/jack mayhoffer
#
#                                              content  rating  \
# 0  I got this portable speaker from Amazon and, l...       5
# 1  Got my hands on this incredible Bluetooth spea...       5
# 2  I really like this Bluetooth speaker; it's sma...       5
# 3  It's a $20 shower speaker so I'll deal with th...       3
# 4  Nice and compact. Good volume. Excellent price...       4
#
#                                             Contents
# 0  i got this portable speaker from amazon and, l...
# 1  got my hands on this incredible bluetooth spea...
# 2  i really like this bluetooth speaker; it's sma...
# ...

# %% [markdown]
# **Analysis of the Sentiment Distribution**

# %% [markdown]
# Calculating the Polarity of the Contents using TextBlob and drop content column

# %%
# Function to classify sentiment based on rating
def classify_sentiment(rating):
    if rating > 3:
        return 'positive'
    elif rating < 3:
        return 'negative'
    else:
        return 'neutral'

# Apply the classification function to the 'rating' column
content_df['sentiment'] = content_df['rating'].apply(classify_sentiment)

content_df
# Out:
#                    product_name                       author  \
# 0     Abitmax bluetooth speaker                          Ned
# 1     Abitmax bluetooth speaker              Bhavani Bhaskar
# 2     Abitmax bluetooth speaker                  Prakashraaz
# 3     Abitmax bluetooth speaker                     cohocook
# 4     Abitmax bluetooth speaker  dirk diggler/jack mayhoffer
# ...                         ...                          ...
# 1378             Beats_pill Red                        B Lii
# 1379             Beats_pill Red                            B
# 1380             Beats_pill Red                   Oli Rivers
# 1381             Beats_pill Red                 Luis dejesus
# 1382             Beats_pill Red                     Dr. Help
#
#                                                 content  rating  \
# 0     I got this portable speaker from Amazon and, l...       5
# 1     Got my hands on this incredible Bluetooth spea...       5
# ...

# %%
neutral_df = content_df[content_df['sentiment'] == 'neutral']
neutral_df
# Out:
#                    product_name      author  \
# 3     Abitmax bluetooth speaker    cohocook
# 41               Beats_pill Red      ERIK H
# 46               Beats_pill Red      Daniel
# 89               Beats_pill Red  Carpe_Diem
# 90               Beats_pill Red       B Lii
# ...                         ...         ...
# 1294             Beats_pill Red       B Lii
# 1329             Beats_pill Red      ERIK H
# 1334             Beats_pill Red      Daniel
# 1377             Beats_pill Red  Carpe_Diem
# 1378             Beats_pill Red       B Lii
#
#                                                 content  rating  \
# 3     It's a $20 shower speaker so I'll deal with th...       3
# 41    Wait for a sale because while it sounds good a...       3
# 46    The new pill looks awesome, and built extremel...       3
# 89    This Bluetooth speaker is on the higher end of...       3
# 90    I was stoked to try a speaker from Beats with ...       3
# ...

# %% [markdown]
# ## **Visualizing Sentiment Distribution with an Interactive Plot**
#
# ---

# %%
# Create the histogram
fig = px.histogram(content_df,
                   x='sentiment',
                   title='Histogram of Customer Sentiments',
                   color='sentiment',
                   category_orders={"sentiment": ["negative", "neutral", "positive"]},  # Ensures ascending order
                   color_discrete_map={"negative": "red", "neutral": "blue", "positive": "green"})  # Color coding

# Customize the layout
fig.update_layout(
    xaxis_title='Sentiment',
    yaxis_title='Frequency',
    title={
        'text': 'Histogram of Customer Sentiments',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    bargap=0.2,
    bargroupgap=0.1
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The plot shows the distribution of customer reviews in the dataset. The breakdown of sentiments is as follows:
#
# - Positive: 1226 contents
# - Negative: 74 contents
# - Neutral: 82 contents

# %%
# Create the histogram with faceting by product_name
fig = px.histogram(content_df,
                   x='sentiment',
                   title='Histogram of Customer Sentiments by Product',
                   color='sentiment',
                   category_orders={"sentiment": ["negative", "neutral", "positive"]},  # Ensures ascending order
                   color_discrete_map={"negative": "red", "neutral": "blue", "positive": "green"},  # Color coding
                   facet_col='product_name',  # Create a separate histogram for each product
                   facet_col_wrap=2)  # Adjust number of columns in the facet layout

# Customize the layout
fig.update_layout(
    xaxis_title='Sentiment',
    yaxis_title='Frequency',
    title={
        'text': 'Histogram of Customer Sentiments by Product',
        'y': 0.9,
        'x': 0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    bargap=0.2,
    bargroupgap=0.1
)

# Show the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The histogram above illustrates the distribution of customer sentiments across various products, focusing on the sentiment categories of negative, neutral, and positive reviews.
#
# Key Observations
# - Beats Pill: The analysis reveals that both Beats Pill products received significant proportion of positive reviews. However, there are also some low levels of both negative and neutral sentiments. This indicates an opportunity for improvement in addressing the concerns reflected in the negative reviews to enhance overall customer satisfaction.
#
# - Competitor Analysis: Several competing products have emerged with notably low or negligible negative sentiment.
#
# These include:
# - JBL Flip 6.
# - Bose SoundLink Flex.
# - Sony ULT Field 1.
#
# Further analysis of these products is recommended to identify the strategies or features contributing to their success in minimizing negative feedback.
#
# Similar Products: Other products that exhibit comparable sentiment distributions across all categories include:
# - Sony SRS-XG300.
# - JBL Charge 5.
# - zealot
#
#
# Highest Negative Reviews: Among the analyzed products, thelenure bluetooth has one of the highest volume of negative reviews, suggesting a need for investigation into customer dissatisfaction and potential areas for improvement.

# %% [markdown]
# ## **Analysis of the Most Common Words**

# %%
# Generate a word cloud
wordcloud = WordCloud(width = 600, height = 500,
                background_color ='white',
                stopwords = None,
                min_font_size = 10).generate(' '.join(content_df['Contents']))

# Plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# **These are some of the key insights uncovered from the most common words in the word cloud:**
#
# Key Insights: - Sound Quality.
# - High Priority: Customers frequently mention "sound" and "bass."
# - Action: Focus on enhancing overall sound and sound quality.
#
#
#
# Ease of Use:
# - Highlighted: Terms like "easy," "bluetooth," and "connect" are common.
# - Action: Ensure reliable and user-friendly Bluetooth connectivity.
#
# Positive Feedback:
# - Common Praise: Words like "great," "happy", "quality",.
# - Action: Maintain high product quality and customer satisfaction.
#
# Product preference:
#  -frequency of words like "beats", "pill", and "show customer preference "

# %% [markdown]
# ## **Visulizing Top 20 Positive Contents using WordCloud**

# %%
# Filter the DataFrame for positive sentiment
positive_text = ' '.join(content_df[content_df['sentiment'].str.lower() == 'positive']['Contents'])

# Generate a word cloud for the top 20 words in positive sentiment
wordcloud = WordCloud(width=400, height=200,
                      background_color='white',
                      stopwords=WordCloud().stopwords,  # Default stopwords
                      min_font_size=10,
                      max_words=20).generate(positive_text)

# Plot the WordCloud image for positive sentiment
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Top 20 Positive Sentiment Contents', size=15)
plt.axis('off')
plt.tight_layout(pad=0)

plt.show()

# %% [markdown]
# **Key Insights from Positive Content:**
#
# - The term "speaker" is prominently mentioned, indicating it is a central feature customers appreciate.
# - "Sound" frequently appears, highlighting its importance in customer satisfaction.
# - Words like "good" and "great" imply strong opinions and favorable feelings about the product.
# - The overwhelming amount of "love" suggests that a large number of consumers are delighted with the purchase.
# - The word "Bose" appears frequently, indicating that consumers evaluate the product favorably to its rival.
# - The product is probably referred to as "one" since it is a top pick or preferred option.
# - "Bass" is frequently highlighted, indicating that it is a significant advantage.
# - The term "sound quality" emphasizes how important it is to client happiness.
# - The word "music" appears frequently, suggesting that people value the product for listening to music.
# - The word "phone" emphasizes how crucial it is that the product work and be used with mobile phones.
# -"Volume" is mentioned a lot, indicating that loudness and volume control are significant to consumers.

# %% [markdown]
# ## **Visulizing Top 20 Negative Contents using WordCloud**

# %%
# Filter the DataFrame for negative sentiment
negative_text = ' '.join(content_df[content_df['sentiment'].str.lower() == 'negative']['Contents'])

# Generate a word cloud for the top 20 words in negative sentiment
wordcloud = WordCloud(width=400, height=200,
                      background_color='white',
                      stopwords=WordCloud().stopwords,  # Default stopwords
                      min_font_size=10,
                      max_words=20).generate(negative_text)

# Plot the WordCloud image for negative sentiment
plt.figure(figsize=(8, 8),
           facecolor=None)
plt.imshow(wordcloud,
           interpolation='bilinear')
plt.title('Top 20 Negative Sentiment Contents',
          size=15)
plt.axis('off')
plt.tight_layout(pad=0)

plt.show()

# %% [markdown]
# The following are the key words frequently mentioned in negative reviews:
#
# -Speaker: Expresses displeasure with the product's speakers' performance and audio quality.
# - Music: Raises doubts about how well the device can handle different musical genres.
# Use: Indicates problems users run into when using the product, potentially pointing to usability problems.
#
# - Brass: Indicates particular grievances regarding sound quality, especially when it comes to the reproduction of brass instruments or particular frequencies.
#
# - Battery: Significant problems with battery life are revealed, suggesting that battery life may fall short of customer expectations.
#
# - Phone: Suggests connectivity issues while utilizing the product with cellphones, which could negatively impact the user experience as a whole.
#
# - Bluetooth: Calls attention to problems that arise when pairing or maintaining a stable Bluetooth connection.
# - Sound: Indicates general complaints about the volume, clarity, and overall performance of the audio output.
# - Time: This could be related to problems with the product's battery life or how long it takes to charge, which would irritate customers.
# - Device: A general word denoting general discontent with the dependability and functionality of the product.
# - Charge: Indicates issues with charging efficiency and speed, which have an impact on consumer happiness.
#
#
# Together, these highlighted terms emphasize important aspects that need to be addressed and improved and highlight major areas of customer dissatisfaction.
#
# .

# %% [markdown]
# Visulizing Top 20 Neutral Contents using WordCloud

# %%
# Filter the DataFrame for neutral sentiment
neutral_text = ' '.join(content_df[content_df['sentiment'].str.lower() == 'neutral']['Contents'])

# Generate a word cloud for the top 20 words in neutral sentiment
wordcloud = WordCloud(width=400, height=200,
                      background_color='white',
                      stopwords=WordCloud().stopwords,  # Default stopwords
                      min_font_size=10,
                      max_words=20).generate(neutral_text)

# Plot the WordCloud image for neutral sentiment
plt.figure(figsize=(8, 8),
           facecolor=None)
plt.imshow(wordcloud,
           interpolation='bilinear')
plt.title('Top 20 Neutral Sentiment Contents',
          size=15)
plt.axis('off')
plt.tight_layout(pad=0)

plt.show()

# %% [markdown]
# **Key Neutral Sentiment Words from Reviews**
#
# The WordCloud image draws attention to the following crucial terms that appear frequently in evaluations that are impartial:
# Bose: Suggests that consumers are aware of competing products available in the market by referencing them.
# - Issue: Indicates the existence of worries or possible issues, without necessarily being negative; it shows a neutral attitude toward the difficulties encountered.
#
# - Device: Provides an unbiased viewpoint on the product's functionality by reflecting a broad phrase for it.
#
# - Sound: Suggested is a conversation about the qualities of sound, with no overtly positive or negative connotations.
#
# - Charge: Alludes to the process of charging a battery, potentially signifying a dispassionate recognition of this attribute.
#
# - Time: Reflecting an unbiased assessment, it suggests a conversation about the length of usage or billing.
#
# - Speaker: Indicates a focus on the product's audio component, mentioned without strong sentiment, perhaps in the context of its design or performance.
# - Will: A neutral term indicating future intentions or predictions regarding the product's use.
# - Bass: Refers to audio quality, particularly low frequencies, mentioned in a way that does not imply satisfaction or dissatisfaction.
# - Volume: Indicates discussions around sound levels, again presented in a neutral context without strong opinions.
# - Product: A general reference to the Beats Pill, reflecting a straightforward acknowledgment of the item being discussed.
# - Music: Suggests a disinterested interaction with the product's features by referencing aural content.
# - Good: Puts it in a neutral context and suggests a mildly positive acknowledgment, but one devoid of passion.
# - Day: Indicates a neutral observation and refers to time, possibly in the context of everyday use.
#
# - Battery: A general discussion of battery performance that is presented in an ambiguous positive or negative manner.
#
# Even: An unbiased word that, depending on the situation, might imply a contrast or clarification.
#
# - Use: Refers to the act of utilizing the thing; it is stated objectively and does not express happiness or discontent.
#
# Together, these italicized terms convey a neutral tone about the Beats Pill and offer insights into the opinions and experiences of customers without a significant emotional impact. This analysis aids in comprehending situations in which clients could feel conflicted or just make objective judgments.

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# In conclusion, useful customer review data was successfully extracted from the JSON files that were scraped from Oxylabs. In order to provide more lucid insights, this analysis effectively combined, cleaned, and examined the dataset. It also addressed missing values and mapped product details. The average rating, according to the results, is 5.0, and 75.68% of the reviews are classified as 5-star, demonstrating a high degree of overall consumer satisfaction. A tiny percentage of poorer evaluations, however, draw attention to variations in user experiences, particularly with regard to features like battery life, sound quality, and usability.
#
# Furthermore, the data revealed that consumer ratings were not much impacted by product price, with both high-end and low-end products receiving largely positive comments. The dataset gains legitimacy from the 80.89% of reviews that were contributed by verified users.
# Sentiment analysis further confirmed the predominance of positive feedback, though certain products, such as the Sony SRS-XE2000, received more critical assessments.
#
# In conclusion, even though the goods performed well overall, the research pointed out several areas with conflicting comments that would need more investigation in order to improve consumer experiences. This methodical methodology guaranteed the data's usefulness and integrity, enabling more in-depth understanding of how customers interacted with the products.

# %% [markdown]
# my API key AIzaSyDNj4M7zIsL4LQN0ye7ACG5X6Nq_PInj6o

# %%
import pandas as pd
import google.generativeai as genai

# Load your dataset
df = pd.read_csv('cleaned_df11.csv')

# Replace 'your_api_key' with the actual API key
api_key = "AIzaSyDNj4M7zIsL4LQN0ye7ACG5X6Nq_PInj6o"

# Function to analyze reviews using Gemini AI
def analyze_reviews(reviews, api_key,prompt_message):
    genai.configure(api_key=api_key)

    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        generation_config={
            "temperature": 1,
            "top_p": 0.95,
            "top_k": 64,
            "max_output_tokens": 8192,
            "response_mime_type": "text/plain",
        },
    )

    chat_session = model.start_chat(history=[])

    prompt = prompt_message + "\n\n".join(reviews)
    response = chat_session.send_message(prompt)
    return response.text

# %%
reviews_column_name = 'content'
reviews = df[reviews_column_name].head(700).tolist() # Use reviews_column_name instead of Content

# Send prompts
prompt_message = "Analyze the following reviews and summarize the key insights:"
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# ## Key Insights from the Reviews:
#
# **General:**
#
# * **High Demand for Portability:**  Most reviewers praise the speakers' compact size and lightweight design, making them ideal for travel, camping, picnics, and even the shower.
# * **Good Sound Quality:**  Many reviews highlight the speakers' surprising sound quality for their size, especially in terms of clear highs and impressive bass.
# * **Strong Battery Life:**  A consistent theme is the long battery life, with many users reporting extended playtime without needing to recharge.
# * **Easy Connectivity:**  Pairing with Bluetooth devices is generally seamless and quick, with most reviewers experiencing no issues in connecting.
# * **Durable and Water-Resistant:** The speakers' durability and water-resistance are often mentioned, making them ideal for outdoor use.
#
# **Specific Insights:**
#
# * **Beats Pill (2024):**
#     *  Impresses with its bass and overall sound quality.
# ...

# %%
reviews_column_name = 'content'
reviews = df[reviews_column_name].head(700).tolist()

# Send prompts
prompt_message = "Analyze the negative reviews and summarize the key pain points:"
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# ## Key Pain Points from Portable Bluetooth Speaker Reviews:
#
# **General:**
#
# * **Battery Life:** Some speakers don't live up to advertised battery life, especially at louder volumes.
# * **Sound Quality:** While many speakers are praised for their sound, some struggle with clarity, especially at higher volumes.
# * **Bass:** Some speakers lack deep bass, while others have excessive bass that can distort sound at higher volumes.
# * **Connectivity:** Issues with Bluetooth connectivity, including random disconnections or difficulty pairing.
# * **Controls:** Confusing or limited controls on some speakers, especially the lack of a dedicated power button.
# * **Durability:** Concerns about speaker durability, with some experiencing damage from minor drops.
# * **Price:** Some feel speakers are overpriced for the features offered.
#
# **Specific Issues:**
#
# ...

# %%
reviews_column_name = 'content'
reviews = df[reviews_column_name].head(700).tolist()

# Send prompts
prompt_message = "You are a data analyst. Analyze the relationship between the 'rating', 'product_price', and 'content' columns in the following dataset and provide insights:"
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# It's impossible to analyze the relationship between "rating," "product_price," and "content" without having the actual dataset with these columns.  The provided text is a collection of reviews, but it doesn't have the structured data required for analysis.
#
# **Here's what I *can* do to help you with a hypothetical analysis:**
#
# 1. **Define the data points:**
#    * **Rating:**  Numerical rating (e.g., 1-5 stars)
#    * **Product_Price:** The price of the speaker (e.g., $20, $150, etc.)
#    * **Content:** The text of the review itself
#
# 2. **Possible Analyses:**
#    * **Correlation between rating and price:**  Do higher-priced speakers tend to receive higher ratings? You could use a scatter plot to visualize this relationship and calculate a correlation coefficient to quantify it.
# ...

# %%
reviews_column_name = 'content'
reviews = df[reviews_column_name].head(100).tolist()

# Send prompts
prompt_message = "You are a data analyst.  using  a chart showrelationship between rating and product_price and provide insights:"
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# I can't create a chart for you directly, but I can help you analyze the text to understand the relationship between rating and product price, and provide insights.
#
# **Here's how we can approach this:**
#
# 1. **Data Extraction:**  We need to extract the following information from the reviews:
#     * **Rating:**  A subjective measure (we can't get numerical ratings, but we can look for positive/negative sentiment).
#     * **Price:**  Look for mentions of price or price range in the reviews.
#     * **Product Name:**  We need to group reviews by product to understand trends.
#
# 2. **Sentiment Analysis:**  Since we don't have explicit numerical ratings, we'll use sentiment analysis to categorize reviews as positive, negative, or neutral.  We can use tools or manually analyze the reviews for keywords and phrases that indicate positive or negative sentiment.
#
# ...

# %%
reviews_column_name = 'content'
reviews = df[reviews_column_name].head(100).tolist()

# Send prompts
prompt_message = "You are a data analyst. give the best performing product based on content and provide insights:"
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# ## Best Performing Product Based on Content Analysis:
#
# **Based on the customer reviews provided, the "Beats Pill 2024" speaker is the best-performing product.** It consistently receives praise for its sound quality, especially its powerful bass and clear highs, along with its long battery life, compact design, and seamless integration with Apple devices.
#
# ## Insights:
#
# **Key Strengths:**
#
# * **Exceptional sound quality:** Customers consistently rave about the balanced audio profile, with powerful bass and clear highs, exceeding expectations for a compact speaker.
# * **Long battery life:** The advertised 24-hour battery life appears to be accurate, with many users reporting extended playtime even with heavy use.
# * **Seamless Apple integration:** The speaker connects easily with Apple devices, offering a streamlined user experience and features like Find My device compatibility.
# ...

# %%
reviews_column_name = 'content'
reviews = df[reviews_column_name].head(100).tolist()

# Send prompts
prompt_message = "You are a data analyst. what is biggest flaw in the following dataset and provide insights:"
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# The biggest flaw in this dataset is the lack of **standardized metrics and objective comparisons**.
#
# Here's a breakdown of the issues and how a data analyst could improve the dataset:
#
# **Problems:**
#
# * **Subjective Reviews:** Most reviews are highly subjective, using words like "amazing," "great," or "good" without concrete measurements. While these provide qualitative insights, they're not useful for analyzing trends or comparing the speaker to competitors.
# * **Lack of Specifics:** Reviews mention "good sound quality" or "great battery life" but don't provide specific details like frequency response, distortion levels, or runtime in hours.
# * **No Baseline:**  It's unclear what other speakers these reviewers are comparing the Beats Pill to. This makes it difficult to understand the speaker's strengths and weaknesses relative to the market.
# ...

# %%
reviews_column_name = 'content'
reviews = df[reviews_column_name].head(100).tolist()

# Send prompts
prompt_message = "You are a data analyst. Analyze content columns in the following dataset and provide insights on which speaker is the most preferred purchse:"
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# Based on the provided dataset, it's difficult to definitively say which speaker is the most preferred purchase. This is because the reviews primarily focus on individual experiences and personal preferences, and there's no clear quantitative measure like sales figures or customer satisfaction ratings.
#
# However, we can glean some insights from the content of the reviews:
#
# **Beats Pill 2024 appears to be a popular choice:** There are a significant number of reviews specifically mentioning the Beats Pill 2024, many of which express positive sentiment. Users highlight features like the powerful sound quality, particularly the bass, long battery life, compact design, and seamless integration with Apple devices.
#
# **Other speakers receive mixed feedback:**  While some other speakers get positive mentions, such as the JBL Flip 6 and Wonderboom, their reviews are more scattered and don't express the same level of enthusiastic endorsement as those for the Beats Pill 2024.
#
# ...
